# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import random
from citipy import citipy
import timeit

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=1500)
lngs = np.random.uniform(-180.000, 180.000, size=1500)

# Create a practice set of random latitude and longitude combinations.
lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269,43.648770,43.870080,10.646530,26.463840,27.463840,19.824592,17.157588]
lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282,-79.381710,-79.440240,-61.471359,-80.818650,-80.818650,-75.867189,2.531249]

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
from citipy import citipy
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = cities.append(citipy.nearest_city(coordinate[0], coordinate[1]).city_name)
    print(coordinates)
    # If the city is unique, then add it to a our cities list
    #if city not in cities:
       # else cities.unique(city) code goes here

# Print the city count to confirm sufficient count
# Out:
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282), (43.64877, -79.38171), (43.87008, -79.44024), (10.64653, -61.471359), (26.46384, -80.81865), (27.46384, -80.81865), (19.824592, -75.867189), (17.157588, 2.531249)]

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests


# Import the datetime module from the datetime library
from datetime import datetime


# Import the time library
import time
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather ["weather"] [0] ["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')     

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                                  "Lat": city_lat,
                                  "Lng": city_lng,
                                  "Max Temp": city_max_temp,
                                  "Humidity": city_humidity,
                                  "Cloudiness": city_clouds,
                                  "Wind Speed": city_wind,
                                  "Country": city_country,
                                  "Current Description": city_description})


    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cockburn town
# {'coord': {'lon': -71.1419, 'lat': 21.4612}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 84.16, 'feels_like': 88.07, 'temp_min': 84.16, 'temp_max': 84.16, 'pressure': 1012, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 100}, 'clouds': {'all': 40}, 'dt': 1665703242, 'sys': {'type': 1, 'id': 7041, 'country': 'TC', 'sunrise': 1665657565, 'sunset': 1665699711}, 'timezone': -14400, 'id': 3576994, 'name': 'Cockburn Town', 'cod': 200}
# Processing Record 2 of Set 1 | gat
# {'coord': {'lon': 34.7642, 'lat': 31.61}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 69.1, 'feels_like': 68.76, 'temp_min': 69.08, 'temp_max': 72.28, 'pressure': 1014, 'humidity': 65, 'sea_level': 1014, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 4.23, 'deg': 296, 'gust': 5.79}, 'clouds': {'all': 28}, 'dt': 1665703072, 'sys': {'type': 2, 'id': 2005256, 'country': 'IL', 'sunrise': 1665718977, 'sunset': 1665760243}, 'timezone': 10800, 'id': 293842, 'name': 'Kiryat Gat', 'cod': 200}
# Processing Record 3 of Set 1 | parvatsar
# {'coord': {'lon': 74.7667, 'lat': 26.8833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 72.09, 'feels_like': 71.29, 'temp_min': 72.09, 'temp_max': 72.09, 'pressure': 1012, 'humidity': 49, 'sea_level': 1012, 'grnd_level': 963}, 'visibility': 10000, 'wind': {'speed': 6.08, 'deg': 135, 'gust': 6.35}, 'clouds': {'all': 0}, 'dt': 1665703242, 'sys': {'country': 'IN', 'sunrise': 1665709171, 'sunset': 1665750851}, 'timezone': 19800, 'id': 1260221, 'name': 'Parvatsar', 'cod': 200}
# Processing Record 4 of Set 1 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 46.51, 'feels_like': 39.36, 'temp_min': 46.11, 'temp_max': 46.51, 'pressure': 1010, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 300}, 'clouds': {'all': 20}, 'dt': 1665703243, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1665654107, 'sunset': 1665703061}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 5 of Set 1 | saint george
# {'coord': {'lon': -113.5841, 'lat': 37.1041}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 85.33, 'feels_like': 82.11, 'temp_min': 82.8, 'temp_max': 89.44, 'pressure': 1016, 'humidity': 13}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 124, 'gust': 5.99}, 'clouds': {'all': 0}, 'dt': 1665703136, 'sys': {'type': 2, 'id': 2008042, 'country': 'US', 'sunrise': 1665668409, 'sunset': 1665709236}, 'timezone': -21600, 'id': 5546220, 'name': 'Saint George', 'cod': 200}
# Processing Record 6 of Set 1 | toronto
# {'coord': {'lon': -79.4163, 'lat': 43.7001}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 53.04, 'feels_like': 51.19, 'temp_min': 50.07, 'temp_max': 54.32, 'pressure': 1005, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 230}, 'clouds': {'all': 0}, 'dt': 1665703243, 'sys': {'type': 1, 'id': 718, 'country': 'CA', 'sunrise': 1665660556, 'sunset': 1665700691}, 'timezone': -14400, 'id': 6167865, 'name': 'Toronto', 'cod': 200}
# Processing Record 7 of Set 1 | toronto
# {'coord': {'lon': -79.4163, 'lat': 43.7001}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 53.04, 'feels_like': 51.19, 'temp_min': 50.07, 'temp_max': 54.32, 'pressure': 1005, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 230}, 'clouds': {'all': 0}, 'dt': 1665703243, 'sys': {'type': 1, 'id': 718, 'country': 'CA', 'sunrise': 1665660556, 'sunset': 1665700691}, 'timezone': -14400, 'id': 6167865, 'name': 'Toronto', 'cod': 200}
# Processing Record 8 of Set 1 | mucurapo
# {'coord': {'lon': -61.5333, 'lat': 10.6667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 80.15, 'feels_like': 85.14, 'temp_min': 80.02, 'temp_max': 80.96, 'pressure': 1013, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 8.01, 'deg': 88, 'gust': 10.2}, 'clouds': {'all': 61}, 'dt': 1665703244, 'sys': {'type': 2, 'id': 2002897, 'country': 'TT', 'sunrise': 1665654883, 'sunset': 1665697781}, 'timezone': -14400, 'id': 3574069, 'name': 'Mucurapo', 'cod': 200}
# Processing Record 9 of Set 1 | belle glade
# {'coord': {'lon': -80.6676, 'lat': 26.6845}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 75.49, 'feels_like': 76.64, 'temp_min': 75.02, 'temp_max': 77.02, 'pressure': 1011, 'humidity': 83, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 9.69, 'deg': 223, 'gust': 16.49}, 'rain': {'1h': 0.12}, 'clouds': {'all': 100}, 'dt': 1665703206, 'sys': {'type': 2, 'id': 2017581, 'country': 'US', 'sunrise': 1665660050, 'sunset': 1665701798}, 'timezone': -14400, 'id': 4147241, 'name': 'Belle Glade', 'cod': 200}
# Processing Record 10 of Set 1 | yeehaw junction
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 11 of Set 1 | santiago de cuba
# {'coord': {'lon': -75.8219, 'lat': 20.0247}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 82.51, 'feels_like': 89.49, 'temp_min': 82.51, 'temp_max': 82.51, 'pressure': 1011, 'humidity': 78}, 'visibility': 9000, 'wind': {'speed': 6.91, 'deg': 220}, 'clouds': {'all': 40}, 'dt': 1665703245, 'sys': {'type': 1, 'id': 7240, 'country': 'CU', 'sunrise': 1665658636, 'sunset': 1665700886}, 'timezone': -14400, 'id': 3536729, 'name': 'Santiago de Cuba', 'cod': 200}
# Processing Record 12 of Set 1 | kidal
# {'coord': {'lon': 1.4078, 'lat': 18.4411}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 87.13, 'feels_like': 83.53, 'temp_min': 87.13, 'temp_max': 87.13, 'pressure': 1013, 'humidity': 12, 'sea_level': 1013, 'grnd_level': 962}, 'visibility': 10000, 'wind': {'speed': 9.93, 'deg': 81, 'gust': 11.72}, 'clouds': {'all': 7}, 'dt': 1665703245, 'sys': {'country': 'ML', 'sunrise': 1665640041, 'sunset': 1665682417}, 'timezone': 0, 'id': 2455290, 'name': 'Kidal', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 11

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cockburn Town  21.4612  -71.1419     84.16        61          40
# 1            Gat  31.6100   34.7642     72.28        65          28
# 2      Parvatsar  26.8833   74.7667     72.09        49           0
# 3   Punta Arenas -53.1500  -70.9167     46.51        57          20
# 4   Saint George  37.1041 -113.5841     89.44        13           0
#
#    Wind Speed Country Current Description
# 0       10.36      TC    scattered clouds
# 1        4.23      IL    scattered clouds
# 2        6.08      IN           clear sky
# 3       18.41      CL          few clouds
# 4        4.00      US           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reorder_columns =["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df =city_data_df[reorder_columns]


# Display sample data
city_data_df.head(11)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0      Cockburn Town      TC  21.4612  -71.1419     84.16        61
# 1                Gat      IL  31.6100   34.7642     72.28        65
# 2          Parvatsar      IN  26.8833   74.7667     72.09        49
# 3       Punta Arenas      CL -53.1500  -70.9167     46.51        57
# 4       Saint George      US  37.1041 -113.5841     89.44        13
# 5            Toronto      CA  43.7001  -79.4163     54.32        67
# 6            Toronto      CA  43.7001  -79.4163     54.32        67
# 7           Mucurapo      TT  10.6667  -61.5333     80.96        84
# 8        Belle Glade      US  26.6845  -80.6676     77.02        83
# 9   Santiago De Cuba      CU  20.0247  -75.8219     82.51        78
# 10             Kidal      ML  18.4411    1.4078     87.13        12
#
#     Cloudiness  Wind Speed Current Description
# 0           40       10.36    scattered clouds
# 1           28        4.23    scattered clouds
# 2            0        6.08           clear sky
# 3           20       18.41          few clouds
# 4            0        4.00           clear sky
# 5            0       18.41           clear sky
# 6            0       18.41           clear sky
# 7           61        8.01       broken clouds
# 8          100        9.69          light rain
# 9           40        6.91    scattered clouds
# 10           7        9.93           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# Export the city_data DataFrame into a CSV file
lats = city_data_df["City"]
lats = city_data_df["Country"]
lats = city_data_df["Lat"]
lats = city_data_df["Lng"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
city_description = city_data_df["Current Description"]
